# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

perov_df = pd.read_csv('perovdata.csv')
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.max_rows', perov_df.shape[0]+1)
print(perov_df)
# Out:
#     Materials Id     Formula     Spacegroup  Formation Energy (eV)  E Above Hull (eV)  Band Gap (eV)   Volume   Nsites  Density (gm/cc) Crystal System
# 0    mp-1079615         Ba2UCdO6      Fm3m          -3.121                0.000            1.884       167.781    10         7.137              cubic
# 1    mp-1205836        Ba2LuMoO6      Fm3m          -3.123                0.000            0.000       148.883    10         7.155              cubic
# 2    mp-1205541        NaScTl2F6      Fm3m          -3.173                0.000            4.764       167.563    10         5.854              cubic
# 3     mp-558194        NaLaMgWO6      C2/m          -2.898                0.000            3.497       250.006    20         6.191         monoclinic
# 4    mp-1206435        Ba2DyTaO6      Fm3m          -3.591                0.000            3.384       155.248    10         7.638              cubic
# ...

# %%
si_df = pd.read_csv('si_data.csv')
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.max_rows', si_df.shape[0]+1)
print(si_df)
# Out:
#    Materials Id Formula Spacegroup  Formation Energy (eV)  E Above Hull (eV)  Band Gap (eV)   Volume   Nsites  Density (gm/cc) Crystal System
# 0       mp-149     Si        Fd3m           0.000                0.000            0.853        40.888      2        2.281              cubic
# 1       mp-165     Si     P63/mmc           0.011                0.011            0.514        81.735      4        2.282          hexagonal
# 2   mp-1203790     Si     P63/mmc           0.056                0.056            1.363      1601.147     68        1.981          hexagonal
# 3    mp-971662     Si        Pm3n           0.062                0.062            1.317      1069.771     46        2.005              cubic
# 4   mp-1079297     Si        C2/m           0.072                0.072            0.288       169.804      8        2.197         monoclinic
# ...

# %%
ga_as_df = pd.read_csv('ga_as_data.csv')
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.max_rows', ga_as_df.shape[0]+1)
print(ga_as_df)
# Out:
#    Materials Id Formula Spacegroup  Formation Energy (eV)  E Above Hull (eV)  Band Gap (eV)   Volume   Nsites  Density (gm/cc) Crystal System
# 0      mp-2534    GaAs      F43m           -0.350                0.000            0.184        47.532      2        5.053              cubic
# 1      mp-8883    GaAs     P63mc           -0.338                0.012            0.192        95.045      4        5.054          hexagonal
# 2     mp-15619    GaAs       Pa3           -0.206                0.144            0.000       350.867     16        5.476              cubic
# 3    mp-603640    GaAs      Imm2           -0.004                0.346            0.000        38.733      2        6.201       orthorhombic
# 4   mp-1245314    GaAs        P1            0.057                0.407            0.000      2363.025    100        5.082          triclinic
# ...
